# %% [markdown]
# # Projet de protection des données
#
# *CERISARA Nathan, DESBERG Clément, JACQUET Ysée, LEVY Lucas*
# *22 janvier 2026*
#
# ## Objectifs du Notebook
#
# TO COMPLETE

# %% [markdown]
# ## Pré-traitement des données

# %% [markdown]
# ## I. KNN

# %% [markdown]
# ## II. CART

# %% [markdown]
# ## III. Random Forest

# %% [markdown]
# ## IV. XGBoost

# %% [markdown]
# ## V. MLP

# %% [markdown]
# ## Comparaison des résultats

# %% [markdown]
# ## Comparaison des performances
